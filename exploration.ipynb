# %% [markdown]
# # Import des tables via duckdb

# %%
import duckdb

DB_PATH = (
    "/home/flocoa/code/Projets/projet-dbt-gbq-streamlit/airbnb_paris.duckdb"
)

# engine de connexion en lecteur only
conn = duckdb.connect(DB_PATH, read_only=True)

# enregistrement des tables dans des DataFrames pandas
df_listings = conn.execute("SELECT * FROM raw.raw_listings").df()
df_calendar = conn.execute("SELECT * FROM raw.raw_calendar").df()
df_reviews = conn.execute("SELECT * FROM raw.raw_reviews").df()

# fermeture de la connexion
conn.close()

# %% [markdown]
# # Exploration de la table 'listings'

# %%
df_listings.head(3)
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  114543  https://www.airbnb.com/rooms/114543  20260616211535   2026-06-21
# 1  115107  https://www.airbnb.com/rooms/115107  20260616211535   2026-06-25
# 2  115655  https://www.airbnb.com/rooms/115655  20260616211535   2026-06-20
#
#             source                                     name  \
# 0      city scrape        Charming 55m² flat - Eiffel Tower
# 1  previous scrape  Charming two-bed apartment with balcony
# 2      city scrape     Family loft with a private courtyard
#
#                                          description neighborhood_overview  \
# 0  Fully furnished charming flat with lots of spa...                  None
# 1  This charming 60 square meter apartment is per...                  None
# 2  Beautiful openplan loft situated in a private,...                  None
#
#                                          picture_url  host_id  ...  \
# ...

# %%
df_listings.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_profile_id', 'host_profile_url', 'host_name',
#        'host_since', 'hosts_time_as_user_years', 'hosts_time_as_user_months',
#        'hosts_time_as_host_years', 'hosts_time_as_host_months',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'latitude', 'longitude',
#        'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
# ...

# %%
df_listings.info()
# Out:
# id                                              77679
# listing_url                                     77679
# scrape_id                                       77679
# last_scraped                                    77679
# source                                          77679
#                                                 ...
# calculated_host_listings_count                  77679
# calculated_host_listings_count_entire_homes     77679
# calculated_host_listings_count_private_rooms    77679
# calculated_host_listings_count_shared_rooms     77679
# reviews_per_month                               61781
# Length: 90, dtype: int64

# %%
df_listings.shape
# Out:
# (77679, 90)

# %%
df_listings.isnull().sum()
# Out:
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# source                                              0
#                                                 ...
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                               15898
# Length: 90, dtype: int64

# %%
# liste des colonnes à ne pas garder car complétements vides
colonnes_vide = []
for col in df_listings.columns:
    if df_listings[col].isnull().sum() == df_listings.shape[0]:
        colonnes_vide.append(col)

# %%
colonnes_vide
# Out:
# ['neighborhood_overview',
#  'host_since',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_thumbnail_url',
#  'host_neighbourhood',
#  'host_total_listings_count',
#  'neighbourhood',
#  'neighbourhood_group_cleansed',
#  'calendar_updated',
#  'instant_bookable']

# %% [markdown]
# # Exploration de la table 'reviews'

# %% [markdown]
# # Exploration de la table 'calendar'
